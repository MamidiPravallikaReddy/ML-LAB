# %% [markdown]
# <a href="https://colab.research.google.com/github/MamidiPravallikaReddy/ML-LAB/blob/main/pandas(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#9
import pandas as pd
data = {'2014':[100.5,150.8,200.9,30000,40000], '2015':[12000,18000,22000,30000,45000], '2016':[20000,50000,70000,100000,125000], '2017':[50000,60000,70000,80000,90000]}
Sales = pd.DataFrame(data, index=['Madhu','Kusum','Kinshuk','Ankit','Shruti'])
Sales
# Out:
#             2014   2015    2016   2017
# Madhu      100.5  12000   20000  50000
# Kusum      150.8  18000   50000  60000
# Kinshuk    200.9  22000   70000  70000
# Ankit    30000.0  30000  100000  80000
# Shruti   40000.0  45000  125000  90000

# %%
#10(a)
Sales.index
# Out:
# Index(['Madhu', 'Kusum', 'Kinshuk', 'Ankit', 'Shruti'], dtype='object')

# %%
#10(b)
Sales.columns
# Out:
# Index(['2014', '2015', '2016', '2017'], dtype='object')

# %%
#10(c)
Sales.dtypes
# Out:
# 2014    float64
# 2015      int64
# 2016      int64
# 2017      int64
# dtype: object

# %%
#10(d)
Sales.shape
# Out:
# (5, 4)

# %%
Sales.size
# Out:
# 20

# %%
Sales.values
# Out:
# array([[1.005e+02, 1.200e+04, 2.000e+04, 5.000e+04],
#        [1.508e+02, 1.800e+04, 5.000e+04, 6.000e+04],
#        [2.009e+02, 2.200e+04, 7.000e+04, 7.000e+04],
#        [3.000e+04, 3.000e+04, 1.000e+05, 8.000e+04],
#        [4.000e+04, 4.500e+04, 1.250e+05, 9.000e+04]])

# %%
Sales.ndim
# Out:
# 2

# %%
#10(e)
Sales.tail(2)
# Out:
#            2014   2015    2016   2017
# Ankit   30000.0  30000  100000  80000
# Shruti  40000.0  45000  125000  90000

# %%
#10(f)
Sales.head(2)
# Out:
#         2014   2015   2016   2017
# Madhu  100.5  12000  20000  50000
# Kusum  150.8  18000  50000  60000

# %%
#10(g)
dict = {'2018':[160000,110000,500000,340000,900000]}
Sales2 = pd.DataFrame(dict, index=['Madhu','Kusum','Kinshuk','Ankit','Shruti'])
Sales2
# Out:
#            2018
# Madhu    160000
# Kusum    110000
# Kinshuk  500000
# Ankit    340000
# Shruti   900000

# %%
#10(h)
Sales2.empty
# Out:
# False

# %%
#11(a)
Sales=pd.concat([Sales, Sales2], axis=1)
Sales
# Out:
#             2014   2015    2016   2017    2018
# Madhu      100.5  12000   20000  50000  160000
# Kusum      150.8  18000   50000  60000  110000
# Kinshuk    200.9  22000   70000  70000  500000
# Ankit    30000.0  30000  100000  80000  340000
# Shruti   40000.0  45000  125000  90000  900000

# %%
#11(b)
Sales.T
# Out:
#          Madhu     Kusum   Kinshuk     Ankit    Shruti
# 2014     100.5     150.8     200.9   30000.0   40000.0
# 2015   12000.0   18000.0   22000.0   30000.0   45000.0
# 2016   20000.0   50000.0   70000.0  100000.0  125000.0
# 2017   50000.0   60000.0   70000.0   80000.0   90000.0
# 2018  160000.0  110000.0  500000.0  340000.0  900000.0

# %%
#11(c)
Sales['2017']
# Out:
# Madhu      50000
# Kusum      60000
# Kinshuk    70000
# Ankit      80000
# Shruti     90000
# Name: 2017, dtype: int64

# %%
#11(d)
Sales.loc[['Madhu', 'Ankit'], ['2017', '2018']]
# Out:
#         2017    2018
# Madhu  50000  160000
# Ankit  80000  340000

# %%
#11(e)
Sales.loc[['Shruti'],['2016']]
# Out:
#             2016
# Shruti  125000.0

# %%
#11(f)
Sales.loc['Sumeet'] = [196.2, 37800, 52000, 78438, 38852]
Sales
# Out:
#             2014     2015      2016     2017      2018
# Madhu      100.5  12000.0   20000.0  50000.0  160000.0
# Kusum      150.8  18000.0   50000.0  60000.0  110000.0
# Kinshuk    200.9  22000.0   70000.0  70000.0  500000.0
# Ankit    30000.0  30000.0  100000.0  80000.0  340000.0
# Shruti   40000.0  45000.0  125000.0  90000.0  900000.0
# Sumeet     196.2  37800.0   52000.0  78438.0   38852.0

# %%
#11(g)
Sales = Sales.drop(columns='2014', errors='ignore')
Sales
# Out:
#             2015      2016     2017      2018
# Madhu    12000.0   20000.0  50000.0  160000.0
# Kusum    18000.0   50000.0  60000.0  110000.0
# Kinshuk  22000.0   70000.0  70000.0  500000.0
# Ankit    30000.0  100000.0  80000.0  340000.0
# Shruti   45000.0  125000.0  90000.0  900000.0
# Sumeet   37800.0   52000.0  78438.0   38852.0

# %%
#11(h)
Sales = Sales.drop(index='Kinshuk', errors='ignore')
Sales
# Out:
#            2015      2016     2017      2018
# Madhu   12000.0   20000.0  50000.0  160000.0
# Kusum   18000.0   50000.0  60000.0  110000.0
# Ankit   30000.0  100000.0  80000.0  340000.0
# Shruti  45000.0  125000.0  90000.0  900000.0
# Sumeet  37800.0   52000.0  78438.0   38852.0

# %%
#11(i)
Sales.rename(index={'Ankit': 'Vivaan', 'Madhu': 'Shailesh'}, inplace=True)
Sales
# Out:
#              2015      2016     2017      2018
# Shailesh  12000.0   20000.0  50000.0  160000.0
# Kusum     18000.0   50000.0  60000.0  110000.0
# Vivaan    30000.0  100000.0  80000.0  340000.0
# Shruti    45000.0  125000.0  90000.0  900000.0
# Sumeet    37800.0   52000.0  78438.0   38852.0

# %%
#11(j)
Sales.loc['Shailesh','2018']=1000000
Sales = Sales.loc[:, ~Sales.columns.duplicated()]
Sales
# Out:
#              2015      2016     2017       2018
# Shailesh  12000.0   20000.0  50000.0  1000000.0
# Kusum     18000.0   50000.0  60000.0   110000.0
# Vivaan    30000.0  100000.0  80000.0   340000.0
# Shruti    45000.0  125000.0  90000.0   900000.0
# Sumeet    37800.0   52000.0  78438.0    38852.0
